# %% [markdown]
# ### Data_Movies.csv:
# File này chứa thông tin tổng hợp của ~ 12 000 bộ film, mỗi bộ film có 24 thuộc tính khác nhau, một số thuộc tính chính bao gồm:
#
# 1. adult: Bộ film dành cho người lớn hay không. Dữ liệu boolean (True - Flase)
# 2. original_language: Ngôn ngữ ban đầu; dữ liệu categorical
# 3. genres: Thể loại film
# 4. original_title: Tiêu đề của film, dữ liệu text
# 5. overview: Tóm tắt nội dung của film; Dữ liệu text
# 6. release_date: Ngày phát hành films
# 7. vote_average: Điểm đánh giá trung bình cho bộ phim [0: dở tệ - 10: Xuất sắc]
# 8. vote_count: Số lượt xem đánh giá bộ phim

# %%
# Import thư viện
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import ast

# %%
#Đọc tập dữ liệu thông tin của các film
file_path = 'Data/Data_Movies.csv'
data = pd.read_csv(file_path)

#Hiển thị thông tin tập dữ liệu
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12182 entries, 0 to 12181
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  12182 non-null  bool
#  1   belongs_to_collection  2409 non-null   object
#  2   budget                 12182 non-null  int64
#  3   genres                 12182 non-null  object
#  4   homepage               3330 non-null   object
#  5   id                     12182 non-null  int64
#  6   imdb_id                12180 non-null  object
#  7   original_language      12182 non-null  object
#  8   original_title         12182 non-null  object
#  9   overview               12119 non-null  object
#  10  popularity             12182 non-null  float64
#  11  poster_path            12182 non-null  object
#  12  production_companies   12182 non-null  object
#  13  production_countries   12182 non-null  object
#  14  release_date           12180 non-null  object
#  15  revenue                12182 non-null  float64
#  16  runtime                12178 non-null  float64
#  17  spoken_languages       12182 non-null  object
#  18  status                 12181 non-null  object
#  19  tagline                8782 non-null   object
#  20  title                  12182 non-null  object
#  21  video                  12182 non-null  bool
#  22  vote_average           12182 non-null  float64
#  23  vote_count             12182 non-null  float64
# dtypes: bool(2), float64(5), int64(2), object(15)
# memory usage: 2.1+ MB

# %%
# Hiển thị 5 dòng đầu
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# Hiển thị thông tin dữ liệu
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12182 entries, 0 to 12181
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  12182 non-null  bool
#  1   belongs_to_collection  2409 non-null   object
#  2   budget                 12182 non-null  int64
#  3   genres                 12182 non-null  object
#  4   homepage               3330 non-null   object
#  5   id                     12182 non-null  int64
#  6   imdb_id                12180 non-null  object
#  7   original_language      12182 non-null  object
#  8   original_title         12182 non-null  object
#  9   overview               12119 non-null  object
#  10  popularity             12182 non-null  float64
#  11  poster_path            12182 non-null  object
#  12  production_companies   12182 non-null  object
#  13  production_countries   12182 non-null  object
#  14  release_date           12180 non-null  object
#  15  revenue                12182 non-null  float64
#  16  runtime                12178 non-null  float64
#  17  spoken_languages       12182 non-null  object
#  18  status                 12181 non-null  object
#  19  tagline                8782 non-null   object
#  20  title                  12182 non-null  object
#  21  video                  12182 non-null  bool
#  22  vote_average           12182 non-null  float64
#  23  vote_count             12182 non-null  float64
# dtypes: bool(2), float64(5), int64(2), object(15)
# memory usage: 2.1+ MB

# %%
# Xử lý cột release_date: Chuyển đổi sang định dạng ngày tháng
data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce')

# Tạo cột year từ release_date
data['year'] = data['release_date'].dt.year

# Tính tỷ lệ lợi nhuận (profit_margin) với điều kiện budget > 0
data['profit_margin'] = data.apply(
    lambda x: (x['revenue'] - x['budget']) / x['budget'] if x['budget'] > 0 else None, axis=1
)

# Xử lý các cột dạng JSON string (genres và production_companies)
def extract_names(json_string):
    try:
        items = ast.literal_eval(json_string)
        return [item['name'] for item in items] if isinstance(items, list) else []
    except (ValueError, SyntaxError):
        return []

data['genres_list'] = data['genres'].apply(extract_names)
data['production_companies_list'] = data['production_companies'].apply(extract_names)

# Thêm cột genres_count (số lượng thể loại mỗi phim)
data['genres_count'] = data['genres_list'].apply(len)

# Điền giá trị thiếu cho runtime và vote_average bằng trung bình
data['runtime'].fillna(data['runtime'].mean(), inplace=True)

# %%
data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 12177  False  {'id': 123720, 'name': 'Frankenstein (Hammer S...         0
# 12178  False                                                NaN         0
# 12179  False                                                NaN         0
# 12180  False                                                NaN         0
# 12181  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 12177  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 12178  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 12179  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 12180  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 12181                     [{'id': 35, 'name': 'Comedy'}]
#
#                                      homepage      id    imdb_id  \
# 0        http://toystory.disney.com/toy-story     862  tt0114709
# 1                                         NaN    8844  tt0113497
# 2                                         NaN   15602  tt0113228
# 3                                         NaN   31357  tt0114885
# 4                                         NaN   11862  tt0113041
# ...                                       ...     ...        ...
# 12177                                     NaN    3104  tt0061683
# 12178                                     NaN  426272  tt6598626
# 12179  https://www.netflix.com/title/80171022  432789  tt5990342
# 12180                                     NaN  455661  tt6969946
# 12181                                     NaN   14008  tt0294425
#
#       original_language                original_title  \
# 0                    en                     Toy Story
# 1                    en                       Jumanji
# 2                    en              Grumpier Old Men
# 3                    en             Waiting to Exhale
# 4                    en   Father of the Bride Part II
# ...                 ...                           ...
# 12177                en    Frankenstein Created Woman
# 12178                en                       Take Me
# 12179                en  The Incredible Jessica James
# 12180                en                In a Heartbeat
# 12181                en                   Cadet Kelly
#
#                                                 overview  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...
# 1      When siblings Judy and Peter discover an encha...  ...
# 2      A family wedding reignites the ancient feud be...  ...
# 3      Cheated on, mistreated and stepped on, the wom...  ...
# 4      Just when George Banks has recovered from his ...  ...
# ...                                                  ...  ...
# 12177  A deformed tormented girl drowns herself after...  ...
# 12178  Ray is a fledgling entrepreneur who specialize...  ...
# 12179  Burned by a bad breakup, a struggling New York...  ...
# 12180  A closeted boy runs the risk of being outed by...  ...
# 12181  Hyperactive teenager Kelly is enrolled into a ...  ...
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 12177  Now Frankenstein has created a beautiful woman...
# 12178                    A good hostage is hard to find.
# 12179                      Likes are easy, love is hard.
# 12180               The Heart Wants What The Heart Wants
# 12181                            Too Cool For The Rules!
#
#                               title  video vote_average vote_count    year  \
# 0                         Toy Story  False          7.7     5415.0  1995.0
# 1                           Jumanji  False          6.9     2413.0  1995.0
# 2                  Grumpier Old Men  False          6.5       92.0  1995.0
# 3                 Waiting to Exhale  False          6.1       34.0  1995.0
# 4       Father of the Bride Part II  False          5.7      173.0  1995.0
# ...                             ...    ...          ...        ...     ...
# 12177    Frankenstein Created Woman  False          5.9       33.0  1967.0
# 12178                       Take Me  False          6.0       38.0  2017.0
# 12179  The Incredible Jessica James  False          6.2       37.0  2017.0
# 12180                In a Heartbeat  False          8.3      146.0  2017.0
# 12181                   Cadet Kelly  False          5.2      145.0  2002.0
#
#        profit_margin                           genres_list  \
# 0          11.451801           [Animation, Comedy, Family]
# 1           3.043035          [Adventure, Fantasy, Family]
# 2                NaN                     [Romance, Comedy]
# 3           4.090760              [Comedy, Drama, Romance]
# 4                NaN                              [Comedy]
# ...              ...                                   ...
# 12177            NaN             [Horror, Science Fiction]
# 12178            NaN                       [Comedy, Crime]
# 12179            NaN                     [Romance, Comedy]
# 12180            NaN  [Family, Animation, Romance, Comedy]
# 12181            NaN                              [Comedy]
#
#                                production_companies_list genres_count
# 0                              [Pixar Animation Studios]            3
# 1      [TriStar Pictures, Teitler Film, Interscope Co...            3
# 2                         [Warner Bros., Lancaster Gate]            2
# 3               [Twentieth Century Fox Film Corporation]            3
# 4           [Sandollar Productions, Touchstone Pictures]            1
# ...                                                  ...          ...
# 12177                          [Hammer Film Productions]            2
# 12178                     [Duplass Brothers Productions]            2
# 12179                                                 []            2
# 12180               [Ringling College of Art and Design]            4
# 12181  [Walt Disney Television, Disney Channel, Leide...            1
#
# [12182 rows x 29 columns]

# %%
# Kiểm tra dữ liệu null
data.isnull().sum()
# Out:
# adult                           0
# belongs_to_collection        9773
# budget                          0
# genres                          0
# homepage                     8852
# id                              0
# imdb_id                         2
# original_language               0
# original_title                  0
# overview                       63
# popularity                      0
# poster_path                     0
# production_companies            0
# production_countries            0
# release_date                    2
# revenue                         0
# runtime                         0
# spoken_languages                0
# status                          1
# tagline                      3400
# title                           0
# video                           0
# vote_average                    0
# vote_count                      0
# year                            2
# profit_margin                6105
# genres_list                     0
# production_companies_list       0
# genres_count                    0
# dtype: int64

# %%
# Loại bỏ các cột không cần thiết
columns_to_drop = ['homepage', 'belongs_to_collection', 'tagline', 'poster_path','genres','production_companies']
data = data.drop(columns=columns_to_drop)

# %%
#Sắp xếp lại dữ liệu theo ngày phát hành
data.sort_values('release_date',axis=0,inplace=True)
data
# Out:
#        adult  budget      id    imdb_id original_language  \
# 9712   False       0     774  tt0000010                fr
# 9272   False       0   82120  tt0000014                fr
# 8291   False       0     160  tt0000012                es
# 5035   False    5985     775  tt0000417                fr
# 5634   False     150    5698  tt0000439                en
# ...      ...     ...     ...        ...               ...
# 11826  False       0  354282  tt4536768                en
# 11338  False       0  300665  tt2620590                en
# 9820   False       0   76600  tt1630029                en
# 11220  False       0  371758  tt3581932                en
# 12009  False       0  409926  tt0081846                en
#
#                                      original_title  \
# 9712            La Sortie de l'Usine Lumière à Lyon
# 9272                             Arroseur et arrosé
# 8291      L'arrivée d'un train en gare de La Ciotat
# 5035                         Le Voyage dans la Lune
# 5634                        The Great Train Robbery
# ...                                             ...
# 11826  Science Fiction Volume One: The Osiris Child
# 11338                                   Leatherface
# 9820                                       Avatar 2
# 11220                      And Then There Were None
# 12009                                        Cosmos
#
#                                                 overview  popularity  \
# 9712   Working men and women leave the Lumière factor...    0.693917
# 9272   A gardener is watering his flowers, when a mis...    1.963421
# 8291   A group of people are standing along the platf...    5.256608
# 5035   A Trip to The Moon is a science fiction film f...    6.321801
# 5634   The clerk at the train station is assaulted an...    4.248169
# ...                                                  ...         ...
# 11826  Set in the future in a time of interplanetary ...   13.454531
# 11338  A young nurse is kidnapped by a group of viole...    9.742082
# 9820                          A sequel to Avatar (2009).    6.020055
# 11220  Ten strangers, drawn away from their normal li...    5.238281
# 12009  Astronomer Dr. Carl Sagan is host and narrator...    0.282584
#
#                                     production_countries release_date  ...  \
# 9712            [{'iso_3166_1': 'FR', 'name': 'France'}]   1895-06-10  ...
# 9272            [{'iso_3166_1': 'FR', 'name': 'France'}]   1895-12-27  ...
# 8291            [{'iso_3166_1': 'FR', 'name': 'France'}]   1896-01-25  ...
# 5035            [{'iso_3166_1': 'FR', 'name': 'France'}]   1902-09-01  ...
# 5634   [{'iso_3166_1': 'US', 'name': 'United States o...   1903-12-01  ...
# ...                                                  ...          ...  ...
# 11826        [{'iso_3166_1': 'AU', 'name': 'Australia'}]   2017-08-31  ...
# 11338  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-09-14  ...
# 9820   [{'iso_3166_1': 'US', 'name': 'United States o...   2020-12-16  ...
# 11220   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]          NaT  ...
# 12009                                                 []          NaT  ...
#
#               status                                         title  video  \
# 9712        Released           Workers Leaving the Lumière Factory  False
# 9272        Released                 Tables Turned on the Gardener  False
# 8291        Released           The Arrival of a Train at La Ciotat  False
# 5035        Released                            A Trip to the Moon  False
# 5634        Released                       The Great Train Robbery  False
# ...              ...                                           ...    ...
# 11826       Released  Science Fiction Volume One: The Osiris Child  False
# 11338       Released                                   Leatherface  False
# 9820   In Production                                      Avatar 2  False
# 11220       Released                      And Then There Were None  False
# 12009       Released                                        Cosmos  False
#
#       vote_average vote_count    year  profit_margin  \
# 9712           6.2       52.0  1895.0            NaN
# 9272           7.0       44.0  1895.0            NaN
# 8291           6.9       87.0  1896.0            NaN
# 5035           7.9      314.0  1902.0           -1.0
# 5634           7.1      116.0  1903.0           -1.0
# ...            ...        ...     ...            ...
# 11826          5.4       55.0  2017.0            NaN
# 11338          5.7       62.0  2017.0            NaN
# 9820           0.0       58.0  2020.0            NaN
# 11220          7.9       91.0     NaN            NaN
# 12009          9.1       41.0     NaN            NaN
#
#                                          genres_list  \
# 9712                                   [Documentary]
# 9272                                        [Comedy]
# 8291                                   [Documentary]
# 5035           [Adventure, Fantasy, Science Fiction]
# 5634                    [Action, Adventure, Western]
# ...                                              ...
# 11826                              [Science Fiction]
# 11338                                       [Horror]
# 9820   [Action, Adventure, Fantasy, Science Fiction]
# 11220                        [Crime, Mystery, Drama]
# 12009                                             []
#
#                                production_companies_list  genres_count
# 9712                                   [Société Lumière]             1
# 9272                                           [Lumière]             1
# 8291                                           [Lumière]             1
# 5035                                         [Star-Film]             3
# 5634                      [Edison Manufacturing Company]             3
# ...                                                  ...           ...
# 11826      [Storm Vision Entertainment, Eclectik Vision]             1
# 11338          [Campbell Grobman Films, LF2 Productions]             1
# 9820   [Twentieth Century Fox Film Corporation, Light...             4
# 11220  [British Broadcasting Corporation (BBC), Mammo...             3
# 12009                                                 []             0
#
# [12182 rows x 23 columns]

# %%
# Loại bỏ các dữ liệu null
data_clear = data.dropna()

# %%
data_clear
# Out:
#        adult    budget      id    imdb_id original_language  \
# 5035   False      5985     775  tt0000417                fr
# 5634   False       150    5698  tt0000439                en
# 10029  False      7500    2963  tt0000499                fr
# 3867   False    100000     618  tt0004972                en
# 3956   False   8394751    3059  tt0006864                en
# ...      ...       ...     ...        ...               ...
# 12151  False  50000000  378236  tt4877122                en
# 12163  False  34000000  407448  tt5390504                en
# 12156  False  11000000  395834  tt5362988                en
# 12142  False  60000000  353491  tt1648190                en
# 12068  False  21000000  293768  tt1458169                en
#
#                                          original_title  \
# 5035                             Le Voyage dans la Lune
# 5634                            The Great Train Robbery
# 10029                     Voyage à travers l'impossible
# 3867                              The Birth of a Nation
# 3956   Intolerance: Love's Struggle Throughout the Ages
# ...                                                 ...
# 12151                                   The Emoji Movie
# 12163                                           Detroit
# 12156                                        Wind River
# 12142                                    The Dark Tower
# 12068                                            Kidnap
#
#                                                 overview  popularity  \
# 5035   A Trip to The Moon is a science fiction film f...    6.321801
# 5634   The clerk at the train station is assaulted an...    4.248169
# 10029  Using every known means of transportation, sev...    1.529176
# 3867   The Birth of A Nation is a silent film from 19...    5.113205
# 3956   The story of a poor young woman, separated by ...    4.282118
# ...                                                  ...         ...
# 12151  Gene, a multi-expressional emoji, sets out on ...   33.694599
# 12163  A police raid in Detroit in 1967 results in on...    9.797505
# 12156  An FBI agent teams with the town's veteran gam...   40.796775
# 12142  The last Gunslinger, Roland Deschain, has been...   50.903593
# 12068  Single mother Karla McCoy lives a perfect life...   20.214579
#
#                                     production_countries release_date  ...  \
# 5035            [{'iso_3166_1': 'FR', 'name': 'France'}]   1902-09-01  ...
# 5634   [{'iso_3166_1': 'US', 'name': 'United States o...   1903-12-01  ...
# 10029           [{'iso_3166_1': 'FR', 'name': 'France'}]   1904-10-01  ...
# 3867   [{'iso_3166_1': 'US', 'name': 'United States o...   1915-02-08  ...
# 3956   [{'iso_3166_1': 'US', 'name': 'United States o...   1916-09-04  ...
# ...                                                  ...          ...  ...
# 12151  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-07-28  ...
# 12163  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-07-28  ...
# 12156  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2017-08-03  ...
# 12142  [{'iso_3166_1': 'ZA', 'name': 'South Africa'},...   2017-08-03  ...
# 12068  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2017-08-04  ...
#
#          status                                             title  video  \
# 5035   Released                                A Trip to the Moon  False
# 5634   Released                           The Great Train Robbery  False
# 10029  Released                             The Impossible Voyage  False
# 3867   Released                             The Birth of a Nation  False
# 3956   Released  Intolerance: Love's Struggle Throughout the Ages  False
# ...         ...                                               ...    ...
# 12151  Released                                   The Emoji Movie  False
# 12163  Released                                           Detroit  False
# 12156  Released                                        Wind River  False
# 12142  Released                                    The Dark Tower  False
# 12068  Released                                            Kidnap  False
#
#       vote_average vote_count    year  profit_margin  \
# 5035           7.9      314.0  1902.0      -1.000000
# 5634           7.1      116.0  1903.0      -1.000000
# 10029          7.1       32.0  1904.0      -1.000000
# 3867           6.4      109.0  1915.0     109.000000
# 3956           7.4       63.0  1916.0      -1.000000
# ...            ...        ...     ...            ...
# 12151          5.8      327.0  2017.0       0.338279
# 12163          7.3       67.0  2017.0      -1.000000
# 12156          7.4      181.0  2017.0      15.797291
# 12142          5.7      688.0  2017.0       0.183333
# 12068          6.0      244.0  2017.0       0.167960
#
#                                              genres_list  \
# 5035               [Adventure, Fantasy, Science Fiction]
# 5634                        [Action, Adventure, Western]
# 10029      [Adventure, Comedy, Fantasy, Science Fiction]
# 3867                               [Drama, History, War]
# 3956                                             [Drama]
# ...                                                  ...
# 12151                        [Comedy, Family, Animation]
# 12163                  [Thriller, Crime, Drama, History]
# 12156                 [Action, Crime, Mystery, Thriller]
# 12142  [Action, Western, Science Fiction, Fantasy, Ho...
# 12068                                  [Drama, Thriller]
#
#                                production_companies_list  genres_count
# 5035                                         [Star-Film]             3
# 5634                      [Edison Manufacturing Company]             3
# 10029                        [Star-Film, Georges Méliès]             4
# 3867                                    [Epoch Film Co.]             3
# 3956   [Triangle Film Corporation, Wark Producing Corp.]             1
# ...                                                  ...           ...
# 12151       [Columbia Pictures, Sony Pictures Animation]             3
# 12163  [Metro-Goldwyn-Mayer (MGM), Annapurna Pictures...             4
# 12156  [Thunder Road Pictures, Star Thrower Entertain...             4
# 12142  [Imagine Entertainment, Weed Road Pictures, Me...             5
# 12068  [Ingenious Media, Di Bonaventura Pictures, Gol...             2
#
# [6071 rows x 23 columns]

# %%
# Kiểm tra lại xem đã loại bỏ hết các giá trị null chưa
data.isnull().sum()
# Out:
# adult                           0
# budget                          0
# id                              0
# imdb_id                         2
# original_language               0
# original_title                  0
# overview                       63
# popularity                      0
# production_countries            0
# release_date                    2
# revenue                         0
# runtime                         0
# spoken_languages                0
# status                          1
# title                           0
# video                           0
# vote_average                    0
# vote_count                      0
# year                            2
# profit_margin                6105
# genres_list                     0
# production_companies_list       0
# genres_count                    0
# dtype: int64

# %%
# Hiển thị lại thông tin của dữ liệu
data_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6071 entries, 5035 to 12068
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   adult                      6071 non-null   bool
#  1   budget                     6071 non-null   int64
#  2   id                         6071 non-null   int64
#  3   imdb_id                    6071 non-null   object
#  4   original_language          6071 non-null   object
#  5   original_title             6071 non-null   object
#  6   overview                   6071 non-null   object
#  7   popularity                 6071 non-null   float64
#  8   production_countries       6071 non-null   object
#  9   release_date               6071 non-null   datetime64[ns]
#  10  revenue                    6071 non-null   float64
#  11  runtime                    6071 non-null   float64
#  12  spoken_languages           6071 non-null   object
#  13  status                     6071 non-null   object
#  14  title                      6071 non-null   object
#  15  video                      6071 non-null   bool
#  16  vote_average               6071 non-null   float64
#  17  vote_count                 6071 non-null   float64
#  18  year                       6071 non-null   float64
#  19  profit_margin              6071 non-null   float64
#  20  genres_list                6071 non-null   object
#  21  production_companies_list  6071 non-null   object
#  22  genres_count               6071 non-null   int64
# dtypes: bool(2), datetime64[ns](1), float64(7), int64(3), object(10)
# memory usage: 1.0+ MB

# %%
#Thống kê các bộ film trùng tên trong tập dữ liệu
data_clear['original_title'].value_counts()
# Out:
# original_title
# Inferno                3
# The Mummy              3
# King Kong              3
# Life                   3
# Alice in Wonderland    3
#                       ..
# The Straight Story     1
# The Story of Us        1
# Random Hearts          1
# Fortress 2             1
# Kidnap                 1
# Name: count, Length: 5939, dtype: int64

# %%
#Sắp xếp film theo thuộc tính vote_count và xóa các film trùng tên, 
#giữ lại film có lượt vote lớn hơn
data_clear.sort_values('vote_count',ascending=True,inplace=True)
data_clear.drop_duplicates(['original_title'],keep='last',inplace=True)
data_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5939 entries, 9558 to 7116
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   adult                      5939 non-null   bool
#  1   budget                     5939 non-null   int64
#  2   id                         5939 non-null   int64
#  3   imdb_id                    5939 non-null   object
#  4   original_language          5939 non-null   object
#  5   original_title             5939 non-null   object
#  6   overview                   5939 non-null   object
#  7   popularity                 5939 non-null   float64
#  8   production_countries       5939 non-null   object
#  9   release_date               5939 non-null   datetime64[ns]
#  10  revenue                    5939 non-null   float64
#  11  runtime                    5939 non-null   float64
#  12  spoken_languages           5939 non-null   object
#  13  status                     5939 non-null   object
#  14  title                      5939 non-null   object
#  15  video                      5939 non-null   bool
#  16  vote_average               5939 non-null   float64
#  17  vote_count                 5939 non-null   float64
#  18  year                       5939 non-null   float64
#  19  profit_margin              5939 non-null   float64
#  20  genres_list                5939 non-null   object
#  21  production_companies_list  5939 non-null   object
#  22  genres_count               5939 non-null   int64
# dtypes: bool(2), datetime64[ns](1), float64(7), int64(3), object(10)
# memory usage: 1.0+ MB

# %%
#Thống kê các bộ film trùng tên trong tập dữ liệu sau xử lý
data_clear['original_title'].value_counts()
# Out:
# original_title
# Secret Défense                 1
# Kramer vs. Kramer              1
# End of Days                    1
# eXistenZ                       1
# Astérix aux Jeux Olympiques    1
#                               ..
# Salem's Lot                    1
# The Human Stain                1
# The Astronaut Farmer           1
# The Red Shoes                  1
# Inception                      1
# Name: count, Length: 5939, dtype: int64

# %%
#Thống kê các dữ liệu trùng nhau
data_clear['overview'].value_counts()
# Out:
# overview
# In France, terrorist groups and intelligence agencies battle in a merciless war everyday, in the name of radically opposed ideologies. Yet, terrorist and secret agents lead almost the same lives. Condemned to secrecy, these masters of manipulation follow the same methods. Alex and Al Barad are two of them. The former is the head of the D.G.S.E.'s (Direction Générale de la Sécurité Extérieure, the French equivalent of the CIA or the MI6) counter-terrorism unit while the latter reigns over a terrorist network, and both fight using the most ruthless of weapons: human beings.    1
# Ted Kramer is a career man for whom his work comes before his family. His wife Joanna cannot take this anymore, so she decides to leave him. Ted is now faced with the tasks of housekeeping and taking care of himself and their young son Billy.                                                                                                                                                                                                                                                                                                                                                    1
# On December 28th, 1999, the citizens of New York City are getting ready for the turn of the millennium. However, the Devil decides to crash the party by coming to the city, inhabiting a man's body, and searching for his chosen bride, a 20-year-old woman named Christine York. The world will end, and the only hope lies within an atheist called Jericho Cane.                                                                                                                                                                                                                                 1
# A game designer on the run from assassins must play her latest virtual reality creation with a marketing trainee to determine if the game has been damaged.                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Astérix and Obélix have to win the Olympic Games in order to help their friend Alafolix marry Princess Irina (portrayed by supermodel Vanessa Hessler). Brutus (Benoît Poelvoorde) uses every trick in the book to have his own team win the game, and get rid of his father Julius Caesar (Alain Delon) in the process.                                                                                                                                                                                                                                                                              1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ..
# Vampires are invading a small New England town. It's up to a novelist and a young horror fan to save it.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Coleman Silk is a worldly and admired professor who loses his job after unwittingly making a racial slur. To clear his name, Silk writes a book about the events with his friend and colleague Nathan Zuckerman, who in the process discovers a dark secret Silk has hidden his whole life. All the while, Silk engages in an affair with Faunia Farley, a younger woman whose tormented past threatens to unravel the layers of deception Silk has constructed.                                                                                                                                      1
# Texan Charles Farmer left the Air Force as a young man to save the family ranch when his dad died. Like most American ranchers, he owes his bank. Unlike most, he's an astrophysicist with a rocket in his barn - one he's built and wants to take into space. It's his dream. The FBI puts him under surveillance when he tries to buy rocket fuel, and the FAA stalls him when he files a flight plan – but Charles is undeterred.                                                                                                                                                                  1
# In this classic drama, Vicky Page is an aspiring ballerina torn between her dedication to dance and her desire to love. While her imperious instructor, Boris Lermontov, urges to her to forget anything but ballet, Vicky begins to fall for the charming young composer Julian Craster. Eventually Vicky, under great emotional stress, must choose to pursue either her art or her romance, a decision that carries serious consequences.                                                                                                                                                          1
# Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person's idea into a target's subconscious.                                                                                                                                                                                                                                                                                                              1
# Name: count, Length: 5939, dtype: int64

# %%
#lọc các bộ film có phần tóm tắt là: No overview found, hoặc No Overview, hoặc chuỗi rỗng, hoặc No movie overview available. 
data_clear.loc[(data_clear['overview']=='No overview found.')].sort_values('overview')
# Out:
# Empty DataFrame
# Columns: [adult, budget, id, imdb_id, original_language, original_title, overview, popularity, production_countries, release_date, revenue, runtime, spoken_languages, status, title, video, vote_average, vote_count, year, profit_margin, genres_list, production_companies_list, genres_count]
# Index: []
#
# [0 rows x 23 columns]

# %%
#Lưu dữ liệu ra file Data_Movies_clear.csv
data_clear.sort_values(['release_date'],inplace=True)
data_clear.reset_index(drop=True,inplace=True)
data_clear.to_csv('D:/streamlit_project/Data/Data_Movies_clear.csv', index=None, encoding='utf-8-sig')
