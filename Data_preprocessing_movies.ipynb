# %% [markdown]
# ### Data_Movies.csv:
# File này chứa thông tin tổng hợp của ~ 12 000 bộ film, mỗi bộ film có 24 thuộc tính khác nhau, một số thuộc tính chính bao gồm:
#
# 1. adult: Bộ film dành cho người lớn hay không. Dữ liệu boolean (True - Flase)
# 2. original_language: Ngôn ngữ ban đầu; dữ liệu categorical
# 3. genres: Thể loại film
# 4. original_title: Tiêu đề của film, dữ liệu text
# 5. overview: Tóm tắt nội dung của film; Dữ liệu text
# 6. release_date: Ngày phát hành films
# 7. vote_average: Điểm đánh giá trung bình cho bộ phim [0: dở tệ - 10: Xuất sắc]
# 8. vote_count: Số lượt xem đánh giá bộ phim

# %%
# Import thư viện
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import ast

# %%
#Đọc tập dữ liệu thông tin của các film
file_path = 'Data/Data_Movies.csv'
data = pd.read_csv(file_path)

#Hiển thị thông tin tập dữ liệu
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12182 entries, 0 to 12181
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  12182 non-null  bool
#  1   belongs_to_collection  2409 non-null   object
#  2   budget                 12182 non-null  int64
#  3   genres                 12182 non-null  object
#  4   homepage               3330 non-null   object
#  5   id                     12182 non-null  int64
#  6   imdb_id                12180 non-null  object
#  7   original_language      12182 non-null  object
#  8   original_title         12182 non-null  object
#  9   overview               12119 non-null  object
#  10  popularity             12182 non-null  float64
#  11  poster_path            12182 non-null  object
#  12  production_companies   12182 non-null  object
#  13  production_countries   12182 non-null  object
#  14  release_date           12180 non-null  object
#  15  revenue                12182 non-null  float64
#  16  runtime                12178 non-null  float64
#  17  spoken_languages       12182 non-null  object
#  18  status                 12181 non-null  object
#  19  tagline                8782 non-null   object
#  20  title                  12182 non-null  object
#  21  video                  12182 non-null  bool
#  22  vote_average           12182 non-null  float64
#  23  vote_count             12182 non-null  float64
# dtypes: bool(2), float64(5), int64(2), object(15)
# memory usage: 2.1+ MB

# %%
# Hiển thị 5 dòng đầu
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# Hiển thị thông tin dữ liệu
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12182 entries, 0 to 12181
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  12182 non-null  bool
#  1   belongs_to_collection  2409 non-null   object
#  2   budget                 12182 non-null  int64
#  3   genres                 12182 non-null  object
#  4   homepage               3330 non-null   object
#  5   id                     12182 non-null  int64
#  6   imdb_id                12180 non-null  object
#  7   original_language      12182 non-null  object
#  8   original_title         12182 non-null  object
#  9   overview               12119 non-null  object
#  10  popularity             12182 non-null  float64
#  11  poster_path            12182 non-null  object
#  12  production_companies   12182 non-null  object
#  13  production_countries   12182 non-null  object
#  14  release_date           12180 non-null  object
#  15  revenue                12182 non-null  float64
#  16  runtime                12178 non-null  float64
#  17  spoken_languages       12182 non-null  object
#  18  status                 12181 non-null  object
#  19  tagline                8782 non-null   object
#  20  title                  12182 non-null  object
#  21  video                  12182 non-null  bool
#  22  vote_average           12182 non-null  float64
#  23  vote_count             12182 non-null  float64
# dtypes: bool(2), float64(5), int64(2), object(15)
# memory usage: 2.1+ MB

# %%
# Xử lý cột release_date: Chuyển đổi sang định dạng ngày tháng
data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce')


# Tạo cột year từ release_date
data['year'] = data['release_date'].dt.year
data['release_date'] = data['release_date'].dt.strftime('%d-%m-%Y')
# Xử lý các cột dạng JSON string (genres và production_companies)
def extract_names(json_string):
    try:
        items = ast.literal_eval(json_string)
        return ','.join(item['name'] for item in items) if isinstance(items, list) else ''
    except (ValueError, SyntaxError):
        return ''

data['genres_list'] = data['genres'].apply(extract_names)
data['production_companies_list'] = data['production_companies'].apply(extract_names)
data['production_countries_list'] = data['production_countries'].apply(extract_names)
data['spoken_language_list'] = data['spoken_languages'].apply(extract_names)

# Chuyển cột id lên dâud
data = data[['id'] + [col for col in data.columns if col != 'id']]

# Điền giá trị thiếu cho runtime và vote_average bằng trung bình
data['runtime'].fillna(data['runtime'].mean(), inplace=True)

# %%
# Kiểm tra dữ liệu null
data.isnull().sum()
# Out:
# id                              0
# adult                           0
# belongs_to_collection        9773
# budget                          0
# genres                          0
# homepage                     8852
# imdb_id                         2
# original_language               0
# original_title                  0
# overview                       63
# popularity                      0
# poster_path                     0
# production_companies            0
# production_countries            0
# release_date                    2
# revenue                         0
# runtime                         0
# spoken_languages                0
# status                          1
# tagline                      3400
# title                           0
# video                           0
# vote_average                    0
# vote_count                      0
# year                            2
# genres_list                     0
# production_companies_list       0
# production_countries_list       0
# spoken_language_list            0
# dtype: int64

# %%
# Xem giá trị cột adult
data['adult'].value_counts()
# Out:
# adult
# False    12182
# Name: count, dtype: int64

# %%
# Xem giá trị cột video
data['video'].value_counts()
# Out:
# video
# False    12177
# True         5
# Name: count, dtype: int64

# %%
#Xem giá trị cột tagline
data['tagline'].value_counts()
# Out:
# tagline
# Based on a true story.                                                                  7
# Be careful what you wish for.                                                           4
# There is no turning back                                                                3
# How far would you go?                                                                   3
# Every second counts.                                                                    2
#                                                                                        ..
# Schmidt Happens                                                                         1
# A generation's final journey... begins.                                                 1
# The hottest chick in town just switched bodies with the luckiest loser in the world.    1
# Half time is game time                                                                  1
# Too Cool For The Rules!                                                                 1
# Name: count, Length: 8733, dtype: int64

# %%
# Xem giá trị cột homapage
data['homepage'].value_counts()
# Out:
# homepage
# http://www.kungfupanda.com/                              4
# http://www.missionimpossible.com/                        4
# http://www.transformersmovie.com/                        4
# http://phantasm.com                                      4
# http://www.thehungergames.movie/                         4
#                                                         ..
# http://www.faqmovie.co.uk/                               1
# http://www.sonyclassics.com/thewhiteribbon/              1
# http://www.fugadecerebros.com/                           1
# https://www.warnerbros.com/green-lantern-first-flight    1
# https://www.netflix.com/title/80171022                   1
# Name: count, Length: 3280, dtype: int64

# %%
# Xem giá trị cột belongs
data['belongs_to_collection'].value_counts()
# Out:
# belongs_to_collection
# {'id': 645, 'name': 'James Bond Collection', 'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg', 'backdrop_path': '/6VcVl48kNKvdXOZfJPdarlUGOsk.jpg'}                   26
# {'id': 34055, 'name': 'Pokémon Collection', 'poster_path': '/j5te0YNZAMXDBnsqTUDKIBEt8iu.jpg', 'backdrop_path': '/iGoYKA0TFfgSoZpG2u5viTJMGfK.jpg'}                   18
# {'id': 425164, 'name': 'Dragon Ball Z (Movie) Collection', 'poster_path': '/2VMZ1zRFPnUQtQp5K4WRXvDYBjh.jpg', 'backdrop_path': '/7PcbijxTfwi9vjWEfXdS0ReAw8q.jpg'}    15
# {'id': 9735, 'name': 'Friday the 13th Collection', 'poster_path': '/uobgqpLQff9WvxGKE2OSvXv1RHm.jpg', 'backdrop_path': '/c7pMKwv5NzIN6N3KM4L8fYMTtPw.jpg'}            12
# {'id': 19163, 'name': 'The Land Before Time Collection', 'poster_path': '/n1bjdBVThBezxR6nEf2dy43sTtV.jpg', 'backdrop_path': '/alkvR9vTtuZEmd5ygsayOfxYOMa.jpg'}      11
#                                                                                                                                                                       ..
# {'id': 109082, 'name': 'Left Behind Collection', 'poster_path': '/x22nc44hxDESi7KTWRGdRFZ9kQ.jpg', 'backdrop_path': '/fumSgqob8LFVMb1zPssRYRLTcTC.jpg'}                1
# {'id': 458558, 'name': 'Mamma Mia! Collection', 'poster_path': None, 'backdrop_path': '/ebetnrgQW2htYdNoB9tygrpmAzW.jpg'}                                              1
# {'id': 363015, 'name': 'Frosty the Snowman Collection', 'poster_path': '/p4W9r7FaSs21P9I6PRjrl6qXrXY.jpg', 'backdrop_path': '/9C08pJcp2gBlHrjb8ArYNG18xX4.jpg'}        1
# {'id': 25542, 'name': 'An American Girl Collection', 'poster_path': '/5JpcRXXuFSgYUgtSKvcdQE9LaMS.jpg', 'backdrop_path': '/1jt2T8oHR1NlzXr7TmSp0Ly9m9D.jpg'}           1
# {'id': 148603, 'name': 'Ducobu Collection', 'poster_path': '/rd7AWZUy2QFPIblNWToVmdfXQcA.jpg', 'backdrop_path': '/7mzKmoIrvGapvsSbAVlX4HtCnFj.jpg'}                    1
# Name: count, Length: 1060, dtype: int64

# %%
# xem các giá trị release_date null
redate_null = data[data['release_date'].isnull()]
redate_null
# Out:
#            id  adult belongs_to_collection  budget  \
# 11220  371758  False                   NaN       0
# 12009  409926  False                   NaN       0
#
#                                                   genres  \
# 11220  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 12009                                                 []
#
#                                        homepage    imdb_id original_language  \
# 11220  http://www.bbc.co.uk/programmes/b06v2v52  tt3581932                en
# 12009                                       NaN  tt0081846                en
#
#                  original_title  \
# 11220  And Then There Were None
# 12009                    Cosmos
#
#                                                 overview  ...  \
# 11220  Ten strangers, drawn away from their normal li...  ...
# 12009  Astronomer Dr. Carl Sagan is host and narrator...  ...
#
#                                   tagline                     title  video  \
# 11220  Agatha Christie's darkest thriller  And Then There Were None  False
# 12009                                 NaN                    Cosmos  False
#
#       vote_average vote_count  year          genres_list  \
# 11220          7.9       91.0   NaN  Crime,Mystery,Drama
# 12009          9.1       41.0   NaN
#
#                                production_companies_list  \
# 11220  British Broadcasting Corporation (BBC),Mammoth...
# 12009
#
#       production_countries_list     spoken_language_list
# 11220            United Kingdom  English,Français,Magyar
# 12009
#
# [2 rows x 29 columns]

# %%
# Loại bỏ các cột không cần thiết
columns_to_drop = ['homepage', 'belongs_to_collection', 'tagline', 'poster_path','genres','production_companies','adult', 'video', 'spoken_languages', 'production_countries']
data = data.drop(columns=columns_to_drop)

# %%
#Sắp xếp lại dữ liệu theo ngày phát hành
data.sort_values('release_date',axis=0,inplace=True)
data
# Out:
#            id  budget    imdb_id original_language             original_title  \
# 4453    58129       0  tt0012364                sv                  Körkarlen
# 3481    14675       0  tt0028597                en            The Awful Truth
# 5751    27040     275  tt0036154                en    Meshes of the Afternoon
# 4238    16391  424000  tt0039192                en            Black Narcissus
# 3643    11898       0  tt0041546                en   Kind Hearts and Coronets
# ...       ...     ...        ...               ...                        ...
# 9611   253295       0  tt1778931                en                      Manny
# 10864  334394       0  tt4935418                tr                     Baskin
# 11211  382517       0  tt4938374                en  Open Season: Scared Silly
# 11220  371758       0  tt3581932                en   And Then There Were None
# 12009  409926       0  tt0081846                en                     Cosmos
#
#                                                 overview  popularity  \
# 4453   It's New Year's Eve. Three drunkards evoke a l...    3.830428
# 3481   Unfounded suspicions lead a married couple to ...    8.105442
# 5751   A woman returning home falls asleep and has vi...    2.574317
# 4238   After opening a convent in the Himalayas, five...    8.657125
# 3643   Louis Mazzini's mother belongs to the aristocr...    9.753718
# ...                                                  ...         ...
# 9611   From abject poverty to becoming a ten-time box...    2.711057
# 10864  Feature length version of the 2013 Turkish sho...    4.173011
# 11211  The humans and animals believe a werewolf is o...    4.452672
# 11220  Ten strangers, drawn away from their normal li...    5.238281
# 12009  Astronomer Dr. Carl Sagan is host and narrator...    0.282584
#
#       release_date  revenue  runtime    status                      title  \
# 4453    01-01-1921      0.0    106.0  Released       The Phantom Carriage
# 3481    01-01-1937      0.0     91.0  Released            The Awful Truth
# 5751    01-01-1943      0.0     14.0  Released    Meshes of the Afternoon
# 4238    01-01-1947      0.0    100.0  Released            Black Narcissus
# 3643    01-01-1949      0.0    106.0  Released   Kind Hearts and Coronets
# ...            ...      ...      ...       ...                        ...
# 9611    31-12-2014      0.0    106.0  Released                      Manny
# 10864   31-12-2015      0.0     97.0  Released                     Baskin
# 11211   31-12-2015      0.0     85.0  Released  Open Season: Scared Silly
# 11220          NaN      0.0    168.0  Released   And Then There Were None
# 12009          NaN      0.0     60.0  Released                     Cosmos
#
#        vote_average  vote_count    year                        genres_list  \
# 4453            7.7        70.0  1921.0               Drama,Fantasy,Horror
# 3481            7.2        48.0  1937.0               Comedy,Drama,Romance
# 5751            7.7        57.0  1943.0             Crime,Mystery,Thriller
# 4238            7.7       106.0  1947.0                              Drama
# 3643            7.6       109.0  1949.0                       Comedy,Drama
# ...             ...         ...     ...                                ...
# 9611            6.4        40.0  2014.0                  Documentary,Drama
# 10864           5.8        73.0  2015.0                     Fantasy,Horror
# 11211           5.5        57.0  2015.0  Animation,Comedy,Family,Adventure
# 11220           7.9        91.0     NaN                Crime,Mystery,Drama
# 12009           9.1        41.0     NaN
#
#                                production_companies_list  \
# 4453                            Svensk Filmindustri (SF)
# 3481                       Columbia Pictures Corporation
# 5751
# 4238                                         The Archers
# 3643                                      Ealing Studios
# ...                                                  ...
# 9611                          Revelin Studios,Wonderspun
# 10864                      Film Colony,XYZ Films,Mo Film
# 11211                            Sony Pictures Animation
# 11220  British Broadcasting Corporation (BBC),Mammoth...
# 12009
#
#              production_countries_list     spoken_language_list
# 4453                            Sweden              No Language
# 3481          United States of America                  English
# 5751          United States of America              No Language
# 4238                    United Kingdom           English,हिन्दी
# 3643                    United Kingdom                  English
# ...                                ...                      ...
# 9611          United States of America                  English
# 10864  Turkey,United States of America                   Türkçe
# 11211         United States of America    Dansk,English,ภาษาไทย
# 11220                   United Kingdom  English,Français,Magyar
# 12009
#
# [12182 rows x 19 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12182 entries, 4453 to 12009
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         12182 non-null  int64
#  1   budget                     12182 non-null  int64
#  2   imdb_id                    12180 non-null  object
#  3   original_language          12182 non-null  object
#  4   original_title             12182 non-null  object
#  5   overview                   12119 non-null  object
#  6   popularity                 12182 non-null  float64
#  7   release_date               12180 non-null  object
#  8   revenue                    12182 non-null  float64
#  9   runtime                    12182 non-null  float64
#  10  status                     12181 non-null  object
#  11  title                      12182 non-null  object
#  12  vote_average               12182 non-null  float64
#  13  vote_count                 12182 non-null  float64
#  14  year                       12180 non-null  float64
#  15  genres_list                12182 non-null  object
#  16  production_companies_list  12182 non-null  object
#  17  production_countries_list  12182 non-null  object
#  18  spoken_language_list       12182 non-null  object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 1.9+ MB

# %%
data.isnull().sum()
# Out:
# id                            0
# budget                        0
# imdb_id                       2
# original_language             0
# original_title                0
# overview                     63
# popularity                    0
# release_date                  2
# revenue                       0
# runtime                       0
# status                        1
# title                         0
# vote_average                  0
# vote_count                    0
# year                          2
# genres_list                   0
# production_companies_list     0
# production_countries_list     0
# spoken_language_list          0
# dtype: int64

# %%
# Loại bỏ các dữ liệu null
data_clear = data.dropna()

# %%
data_clear
# Out:
#            id    budget    imdb_id original_language  \
# 4453    58129         0  tt0012364                sv
# 3481    14675         0  tt0028597                en
# 5751    27040       275  tt0036154                en
# 4238    16391    424000  tt0039192                en
# 3643    11898         0  tt0041546                en
# ...       ...       ...        ...               ...
# 9682   227359  10000000  tt2611626                en
# 10600  298614         0  tt3667648                fr
# 9611   253295         0  tt1778931                en
# 10864  334394         0  tt4935418                tr
# 11211  382517         0  tt4938374                en
#
#                   original_title  \
# 4453                   Körkarlen
# 3481             The Awful Truth
# 5751     Meshes of the Afternoon
# 4238             Black Narcissus
# 3643    Kind Hearts and Coronets
# ...                          ...
# 9682          Force of Execution
# 10600  Une heure de tranquillité
# 9611                       Manny
# 10864                     Baskin
# 11211  Open Season: Scared Silly
#
#                                                 overview  popularity  \
# 4453   It's New Year's Eve. Three drunkards evoke a l...    3.830428
# 3481   Unfounded suspicions lead a married couple to ...    8.105442
# 5751   A woman returning home falls asleep and has vi...    2.574317
# 4238   After opening a convent in the Himalayas, five...    8.657125
# 3643   Louis Mazzini's mother belongs to the aristocr...    9.753718
# ...                                                  ...         ...
# 9682   Seagal stars as mob kingpin Mr. Alexander, an ...    2.151259
# 10600  Michel, who's crazy about jazz, has just found...    5.756279
# 9611   From abject poverty to becoming a ten-time box...    2.711057
# 10864  Feature length version of the 2013 Turkish sho...    4.173011
# 11211  The humans and animals believe a werewolf is o...    4.452672
#
#       release_date  revenue  runtime    status                      title  \
# 4453    01-01-1921      0.0    106.0  Released       The Phantom Carriage
# 3481    01-01-1937      0.0     91.0  Released            The Awful Truth
# 5751    01-01-1943      0.0     14.0  Released    Meshes of the Afternoon
# 4238    01-01-1947      0.0    100.0  Released            Black Narcissus
# 3643    01-01-1949      0.0    106.0  Released   Kind Hearts and Coronets
# ...            ...      ...      ...       ...                        ...
# 9682    31-12-2013      0.0     98.0  Released         Force of Execution
# 10600   31-12-2014      0.0     79.0  Released             Do Not Disturb
# 9611    31-12-2014      0.0    106.0  Released                      Manny
# 10864   31-12-2015      0.0     97.0  Released                     Baskin
# 11211   31-12-2015      0.0     85.0  Released  Open Season: Scared Silly
#
#        vote_average  vote_count    year                        genres_list  \
# 4453            7.7        70.0  1921.0               Drama,Fantasy,Horror
# 3481            7.2        48.0  1937.0               Comedy,Drama,Romance
# 5751            7.7        57.0  1943.0             Crime,Mystery,Thriller
# 4238            7.7       106.0  1947.0                              Drama
# 3643            7.6       109.0  1949.0                       Comedy,Drama
# ...             ...         ...     ...                                ...
# 9682            5.1        34.0  2013.0                       Action,Crime
# 10600           5.3       113.0  2014.0                             Comedy
# 9611            6.4        40.0  2014.0                  Documentary,Drama
# 10864           5.8        73.0  2015.0                     Fantasy,Horror
# 11211           5.5        57.0  2015.0  Animation,Comedy,Family,Adventure
#
#                                production_companies_list  \
# 4453                            Svensk Filmindustri (SF)
# 3481                       Columbia Pictures Corporation
# 5751
# 4238                                         The Archers
# 3643                                      Ealing Studios
# ...                                                  ...
# 9682            Steamroller Productions,Voltage Pictures
# 10600  Wild Bunch,TF1 Films Production,Canal+,Orange ...
# 9611                          Revelin Studios,Wonderspun
# 10864                      Film Colony,XYZ Films,Mo Film
# 11211                            Sony Pictures Animation
#
#              production_countries_list               spoken_language_list
# 4453                            Sweden                        No Language
# 3481          United States of America                            English
# 5751          United States of America                        No Language
# 4238                    United Kingdom                     English,हिन्दी
# 3643                    United Kingdom                            English
# ...                                ...                                ...
# 9682          United States of America                            English
# 10600                           France  Français,Polski,Português,Español
# 9611          United States of America                            English
# 10864  Turkey,United States of America                             Türkçe
# 11211         United States of America              Dansk,English,ภาษาไทย
#
# [12114 rows x 19 columns]

# %%
# Kiểm tra lại xem đã loại bỏ hết các giá trị null chưa
data_clear.isnull().sum()
# Out:
# id                           0
# budget                       0
# imdb_id                      0
# original_language            0
# original_title               0
# overview                     0
# popularity                   0
# release_date                 0
# revenue                      0
# runtime                      0
# status                       0
# title                        0
# vote_average                 0
# vote_count                   0
# year                         0
# genres_list                  0
# production_companies_list    0
# production_countries_list    0
# spoken_language_list         0
# dtype: int64

# %%
# Hiển thị lại thông tin của dữ liệu
data_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12114 entries, 4453 to 11211
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         12114 non-null  int64
#  1   budget                     12114 non-null  int64
#  2   imdb_id                    12114 non-null  object
#  3   original_language          12114 non-null  object
#  4   original_title             12114 non-null  object
#  5   overview                   12114 non-null  object
#  6   popularity                 12114 non-null  float64
#  7   release_date               12114 non-null  object
#  8   revenue                    12114 non-null  float64
#  9   runtime                    12114 non-null  float64
#  10  status                     12114 non-null  object
#  11  title                      12114 non-null  object
#  12  vote_average               12114 non-null  float64
#  13  vote_count                 12114 non-null  float64
#  14  year                       12114 non-null  float64
#  15  genres_list                12114 non-null  object
#  16  production_companies_list  12114 non-null  object
#  17  production_countries_list  12114 non-null  object
#  18  spoken_language_list       12114 non-null  object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 1.8+ MB

# %%
#Thống kê các bộ film trùng tên trong tập dữ liệu
data_clear['original_title'].value_counts()
# Out:
# original_title
# The Mummy                    4
# Life                         4
# Frankenstein                 4
# Wuthering Heights            4
# A Christmas Carol            4
#                             ..
# Pooh's Heffalump Movie       1
# La science des rêves         1
# Goodbye Bafana               1
# The Wolfman                  1
# Open Season: Scared Silly    1
# Name: count, Length: 11761, dtype: int64

# %%
#Sắp xếp film theo thuộc tính vote_count và xóa các film trùng tên, 
#giữ lại film có lượt vote lớn hơn
data_clear.sort_values('vote_count',ascending=True,inplace=True)
data_clear.drop_duplicates(['original_title'],keep='last',inplace=True)
data_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11761 entries, 4508 to 7116
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         11761 non-null  int64
#  1   budget                     11761 non-null  int64
#  2   imdb_id                    11761 non-null  object
#  3   original_language          11761 non-null  object
#  4   original_title             11761 non-null  object
#  5   overview                   11761 non-null  object
#  6   popularity                 11761 non-null  float64
#  7   release_date               11761 non-null  object
#  8   revenue                    11761 non-null  float64
#  9   runtime                    11761 non-null  float64
#  10  status                     11761 non-null  object
#  11  title                      11761 non-null  object
#  12  vote_average               11761 non-null  float64
#  13  vote_count                 11761 non-null  float64
#  14  year                       11761 non-null  float64
#  15  genres_list                11761 non-null  object
#  16  production_companies_list  11761 non-null  object
#  17  production_countries_list  11761 non-null  object
#  18  spoken_language_list       11761 non-null  object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 1.8+ MB

# %%
#Thống kê các bộ film trùng tên trong tập dữ liệu sau xử lý
data_clear['original_title'].value_counts()
# Out:
# original_title
# 人間の條件　第３部望郷篇／第４部戦雲篇                   1
# Neuilly sa Mère !                     1
# Copycat                               1
# Død Snø 2                             1
# Bambi II                              1
#                                      ..
# 中国合伙人                                 1
# Whisper                               1
# The Lion Guard: Return of the Roar    1
# Gorky Park                            1
# Inception                             1
# Name: count, Length: 11761, dtype: int64

# %%
#Thống kê các dữ liệu trùng nhau
data_clear['overview'].value_counts()
# Out:
# overview
# No overview found.                                                                                                                                                                                                                                                                                                                                                                                                       8
# A few funny little novels about different aspects of life.                                                                                                                                                                                                                                                                                                                                                               3
# Kaji, having lost his exemption from military service by protecting Chinese prisoners from unjust punishment, has now been conscripted into the Japanese Kwantung Army. Despite his anti-militarism, Kaji excels in his training and tries to implement his ideals in his dealings with other soldiers in the face of the prevailing brutality. The film ends with the Soviet army's victorious onslaught.               1
# A young prosecutor in postwar West Germany investigates a massive conspiracy to cover up the Nazi pasts of prominent public figures.                                                                                                                                                                                                                                                                                     1
# Wallace and Gromit have run out of cheese and this provides an excellent excuse for the animated duo to take their holiday on the moon, where, as everyone knows, there is ample cheese. The moon is inhabited by a mechanical caretaker, who is not too happy about the two visitors from earth that nibble on the moon.                                                                                                1
#                                                                                                                                                                                                                                                                                                                                                                                                                         ..
# Set in the African savannah, the film follows Kion as he assembles the members of the 'Lion Guard'. Throughout the film, the diverse team of young animals will learn how to utilize each of their unique abilities to solve problems and accomplish tasks to maintain balance within the Circle of Life, while also introducing viewers to the vast array of animals that populate the prodigious African landscape.    1
# Police Inspector Renko tries to solve the case of three bodies found in Moscow's Gorky Park but finds his attempts to solve the crime impeded by his superiors. Working on his own, Renko seeks out more information and stumbles across a conspiracy involving the highest levels of the government.                                                                                                                    1
# An up-and-coming poker player tries to prove himself in a high-stakes match against a long-time master of the game.                                                                                                                                                                                                                                                                                                      1
# In 1998, an auction of the estate of the Duke and Duchess of Windsor causes great excitement. For one woman, Wally Winthrop, it has much more meaning. Wally becomes obsessed by their historic love story. As she learns more about the sacrifices involved, Wally gains her own courage to find happiness.                                                                                                             1
# Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person's idea into a target's subconscious.                                                                                                                                 1
# Name: count, Length: 11752, dtype: int64

# %%
#lọc các bộ film có phần tóm tắt là: No overview found, hoặc No Overview, hoặc chuỗi rỗng, hoặc No movie overview available. 
data_clear.loc[(data_clear['overview']=='No overview found.')].sort_values('overview')
# Out:
#           id  budget    imdb_id original_language  \
# 10516  22182       0  tt1065305                en
# 10103  10036       0  tt0461642                de
# 11093  13713       0  tt0477988                fr
# 8078   20106       0  tt0338828                fr
# 5024    2029       0  tt0274155                en
# 10612  26285       0  tt0085524                it
# 9721   20414       0  tt1077026                en
# 10566  24169       0  tt1288637                it
#
#                             original_title            overview  popularity  \
# 10516                Lezioni di cioccolato  No overview found.    2.064569
# 10103  7 Zwerge - Der Wald ist nicht genug  No overview found.    6.637562
# 11093                        Jean-Philippe  No overview found.    2.872268
# 8078          Mais qui a tué Pamela Rose ?  No overview found.    3.065777
# 5024                                Tanguy  No overview found.    3.360530
# 10612              Fantozzi subisce ancora  No overview found.    4.434073
# 9721              Grande, grosso e Verdone  No overview found.    4.309426
# 10566                    Il cosmo sul comò  No overview found.    3.935385
#
#       release_date  revenue  runtime    status  \
# 10516   23-11-2007      0.0     99.0  Released
# 10103   25-10-2006      0.0     95.0  Released
# 11093   05-04-2006      0.0      0.0  Released
# 8078    04-06-2003      0.0     95.0  Released
# 5024    21-11-2001      0.0    108.0  Released
# 10612   01-01-1983      0.0     85.0  Released
# 9721    07-03-2008      0.0      0.0  Released
# 10566   19-12-2008      0.0    100.0  Released
#
#                                      title  vote_average  vote_count    year  \
# 10516                Lezioni di cioccolato           5.8        42.0  2007.0
# 10103  7 Dwarves: The Forest Is Not Enough           4.9        44.0  2006.0
# 11093                        Jean-Philippe           5.4        48.0  2006.0
# 8078          Mais qui a tué Pamela Rose ?           6.6        62.0  2003.0
# 5024                                Tanguy           5.8        70.0  2001.0
# 10612               Fantozzi Still Suffers           6.4        77.0  1983.0
# 9721              Grande, grosso e Verdone           5.6        78.0  2008.0
# 10566                    Il cosmo sul comò           5.0       156.0  2008.0
#
#       genres_list                          production_companies_list  \
# 10516      Comedy
# 10103      Comedy                                 Universal Pictures
# 11093      Comedy  Fidélité Productions,StudioCanal,TF1 Films Pro...
# 8078       Comedy  Gaumont,LGM Productions,TF1 Films Production,C...
# 5024       Comedy  Les Productions du Champ Poirier,TPS Cinéma,TF...
# 10612      Comedy
# 9721       Family                                           Filmauro
# 10566      Comedy
#
#       production_countries_list spoken_language_list
# 10516                     Italy             Italiano
# 10103                   Germany              Deutsch
# 11093                    France             Français
# 8078                     France             Français
# 5024                     France             Français
# 10612                     Italy             Italiano
# 9721                      Italy             Italiano
# 10566                     Italy             Italiano

# %%
#Có tất cả 8 bộ film không có dữ liệu tóm tắt film:
#Xóa các bộ film này
data_clear = data_clear.loc[(data_clear['overview']!='No overview found.')]
data_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11753 entries, 4508 to 7116
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         11753 non-null  int64
#  1   budget                     11753 non-null  int64
#  2   imdb_id                    11753 non-null  object
#  3   original_language          11753 non-null  object
#  4   original_title             11753 non-null  object
#  5   overview                   11753 non-null  object
#  6   popularity                 11753 non-null  float64
#  7   release_date               11753 non-null  object
#  8   revenue                    11753 non-null  float64
#  9   runtime                    11753 non-null  float64
#  10  status                     11753 non-null  object
#  11  title                      11753 non-null  object
#  12  vote_average               11753 non-null  float64
#  13  vote_count                 11753 non-null  float64
#  14  year                       11753 non-null  float64
#  15  genres_list                11753 non-null  object
#  16  production_companies_list  11753 non-null  object
#  17  production_countries_list  11753 non-null  object
#  18  spoken_language_list       11753 non-null  object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 1.8+ MB

# %%
dt = data_clear[data_clear['spoken_language_list'] =='']
dt
# Out:
#            id    budget    imdb_id original_language  \
# 7895    70585         0  tt1473397                en
# 9130   168742   1525000  tt2178256                lo
# 3235    37964   8000000  tt0297037                en
# 5146    28201         0  tt0443518                en
# 4459    27517         0  tt0019130                en
# 9861    38580         0  tt0816562                en
# 2795     5998         0  tt0013086                de
# 9690   276918         0  tt2785390                en
# 9734    18729         0  tt0088583                en
# 12061   24914         0  tt0368574                en
# 9493   286817         0  tt3546114                en
# 10986  315620         0  tt1672218                en
# 10242  283322         0  tt3399916                en
# 3875    32318         0  tt0015163                en
# 7711    75311         0  tt1325014                en
# 9441   234862    295000  tt3043542                fr
# 9340     3171         0  tt0064064                en
# 9856    53215         0  tt1051713                en
# 4864     1114         0  tt0373861                mn
# 9710   142563         0  tt2309977                en
# 11761   31160         0  tt1490530                en
# 7648    67885         0  tt1777551                en
# 8861    70338         0  tt1696192                en
# 3423    27088         0  tt0084234                en
# 4963     8340         0  tt0424227                fa
# 9715    37777         0  tt0086850                en
# 6212    14019         0  tt0812243                nl
# 8073    49084         0  tt0889665                en
# 9103   158091         0  tt1845838                tl
# 4460    25768         0  tt0019421                en
# 11060  373977         0  tt4146128                en
# 6327   118309         0  tt0472027                en
# 10125  265019         0  tt3138558                en
# 5123     1665         0  tt0403217                en
# 390     25059         0  tt0116552                en
# 8491    30675         0  tt1483025                en
# 10664  253687         0  tt2536428                fr
# 6914    22164   3700000  tt0346631                en
# 8024    34433         0  tt0142242                ja
# 7347    40619         0  tt1620446                en
# 798       653         0  tt0013442                de
# 8478   109410  40000000  tt0453562                en
#
#                                    original_title  \
# 7895                                        Lucky
# 9130                                   The Rocket
# 3235                                  Brown Sugar
# 5146                         The Girl in the Café
# 4459                           The Man Who Laughs
# 9861                         The Little Matchgirl
# 2795                      Dr. Mabuse, der Spieler
# 9690       America: Imagine the World Without Her
# 9734                      North and South, Book I
# 12061                                 Kid's Story
# 9493                       Anatomy of a Love Seen
# 10986               Doctor Who: A Christmas Carol
# 10242                              The Dead Lands
# 3875                                The Navigator
# 7711                  The People vs. George Lucas
# 9441                                    Mr Hublot
# 9340                         Bambi Meets Godzilla
# 9856                                        Kiwi!
# 4864           Die Geschichte vom weinenden Kamel
# 9710                              Fresh Guacamole
# 11761                                        Alma
# 7648              Bobby Fischer Against the World
# 8861   A Fairly Odd Movie: Grow Up, Timmy Turner!
# 3423                     The Last American Virgin
# 4963                  لاک‌پشت‌ها هم پرواز می‌کنند
# 9715                               Acqua e sapone
# 6212                                   Ex Drummer
# 8073                                        Steak
# 9103                                 Metro Manila
# 4460                          Steamboat Bill, Jr.
# 11060                             Childhood's End
# 6327                                   John Adams
# 10125                                Preservation
# 5123                                    Last Days
# 390      Homeward Bound II: Lost in San Francisco
# 8491                                  Planet Hulk
# 10664                        La crème de la crème
# 6914                               Blood and Bone
# 8024                    ドラゴンボールＺ 燃え尽きろ!!熱戦・烈戦・超激戦
# 7347                                  Day & Night
# 798         Nosferatu, eine Symphonie des Grauens
# 8478                                           42
#
#                                                 overview  popularity  \
# 7895   A wannabe serial killer wins the lottery and p...    8.954166
# 9130   Set against the lush backdrop of rural Laos, t...    1.665135
# 3235   Sidney is a writer who's just left her L.A. Ti...    3.142874
# 5146   Lawrence, an aging, lonely civil servant falls...    3.829855
# 4459   Gwynplaine, son of Lord Clancharlie, has a per...    2.571104
# 9861   An animated short based on Hans Christian Ande...    3.529071
# 2795   Arch-criminal Dr. Mabuse, who is a master of d...    3.275117
# 9690   Political commentator, author and filmmaker Di...    1.313952
# 9734   Two friends, one northern and one southern, st...    2.238623
# 12061  A high school student is haunted by thoughts o...    3.253814
# 9493   From Writer/Director Marina Rice Bader (Execut...    2.134277
# 10986  Amy Pond and Rory Williams are trapped on a cr...    2.906731
# 10242  Hongi, a Maori chieftain’s teenage son, must a...   10.001517
# 3875   Two spoiled rich people find themselves trappe...    3.031803
# 7711   The passion the original Star Wars trilogy ins...    2.466945
# 9441   Mr Hublot is a withdrawn, idiosyncratic charac...    2.910784
# 9340   Bambi is nibbling the grass, unaware of the up...    2.032918
# 9856   The story of a Kiwi who spends his whole life ...    1.994703
# 4864   When a Mongolian nomadic family's newest camel...    2.799536
# 9710   In this follow-up to his stop-motion hit Weste...    4.406065
# 11761  Alma, a little girl, skips through the snow co...    1.700431
# 7648   The first documentary feature to explore the t...    2.234857
# 8861   The television movie is set in the city of Dim...    3.694115
# 3423   The friendship of a group of young friends str...    9.390673
# 4963   Turtles can fly tells the story of a group of ...    3.281608
# 9715   La madre-manager di una giovanissima modella a...    2.058947
# 6212   Three handicapped losers who form a band ask f...    3.624061
# 8073   A French comedy with comedians Eric &amp; Ramz...    2.669195
# 9103   Seeking a brighter future in megacity Manila, ...    2.853241
# 4460   The just out of college effete son of a no-non...    7.518657
# 11060  After peaceful aliens invade earth, humanity f...    2.856502
# 6327   The life of one of the USA's Founding Fathers,...    2.794764
# 10125  Three family members head deep into the woods ...    5.092349
# 5123   The life and struggles of a notorious rock mus...    4.790012
# 390    Your favorite talking animals are back! The fi...   14.657754
# 8491   When the Hulk becomes too dangerous for the Ea...    5.769957
# 10664  Kelly, Dan and Louis are students at a prestig...    3.973512
# 6914   In Los Angeles, an ex-con (White) takes the un...   12.673118
# 8024   As Goku investigates the destruction of the So...    7.348249
# 7347   When Day, a sunny fellow, encounters Night, a ...    6.345512
# 798    Vampire Count Orlok is interested in a new res...    7.435873
# 8478   The powerful story of Jackie Robinson, the leg...   11.637224
#
#       release_date     revenue  runtime    status  \
# 7895    15-07-2011         0.0    103.0  Released
# 9130    10-02-2013         0.0     96.0  Released
# 3235    05-10-2002  27362712.0    109.0  Released
# 5146    25-06-2005         0.0     94.0  Released
# 4459    27-04-1928         0.0    110.0  Released
# 9861    07-09-2006         0.0      7.0  Released
# 2795    27-04-1922         0.0    270.0  Released
# 9690    02-07-2014         0.0    103.0  Released
# 9734    03-11-1985         0.0    561.0  Released
# 12061   02-06-2003         0.0     15.0  Released
# 9493    28-07-2014         0.0     86.0  Released
# 10986   25-12-2010         0.0     62.0  Released
# 10242   04-09-2014      5240.0    108.0  Released
# 3875    13-10-1924         0.0     59.0  Released
# 7711    14-03-2010         0.0     93.0  Released
# 9441    14-10-2013         0.0     11.0  Released
# 9340    01-01-1969         0.0      2.0  Released
# 9856    01-01-2006         0.0      3.0  Released
# 4864    29-06-2003         0.0     91.0  Released
# 9710    02-03-2012         0.0      2.0  Released
# 11761   01-01-2009         0.0      6.0  Released
# 7648    06-06-2011         0.0     93.0  Released
# 8861    09-07-2011         0.0     57.0  Released
# 3423    26-06-1982         0.0     92.0  Released
# 4963    07-01-2005         0.0     98.0  Released
# 9715    27-10-1983         0.0    109.0  Released
# 6212    31-01-2007         0.0     90.0  Released
# 8073    20-06-2007         0.0     82.0  Released
# 9103    20-01-2013         0.0    114.0  Released
# 4460    14-02-1928         0.0     70.0  Released
# 11060   14-12-2015         0.0    246.0  Released
# 6327    16-03-2008         0.0    501.0  Released
# 10125   22-08-2014         0.0     90.0  Released
# 5123    13-05-2005   1928985.0     96.0  Released
# 390     08-03-1996  32709423.0     89.0  Released
# 8491    02-02-2010   7000000.0     81.0  Released
# 10664   02-04-2014         0.0     90.0  Released
# 6914    07-02-2009         0.0     93.0  Released
# 8024    06-03-1993         0.0     70.0  Released
# 7347    17-06-2010         0.0      6.0  Released
# 798     15-03-1922         0.0     94.0  Released
# 8478    12-04-2013  95020213.0    128.0  Released
#
#                                                    title  vote_average  \
# 7895                                               Lucky           4.9
# 9130                                          The Rocket           6.8
# 3235                                         Brown Sugar           7.0
# 5146                                The Girl in the Café           6.6
# 4459                                  The Man Who Laughs           7.4
# 9861                                The Little Matchgirl           7.3
# 2795                             Dr. Mabuse, the Gambler           7.6
# 9690              America: Imagine the World Without Her           5.4
# 9734                             North and South, Book I           6.9
# 12061                                        Kid's Story           7.2
# 9493                              Anatomy of a Love Seen           4.5
# 10986                      Doctor Who: A Christmas Carol           7.9
# 10242                                     The Dead Lands           6.1
# 3875                                       The Navigator           7.3
# 7711                         The People vs. George Lucas           6.2
# 9441                                           Mr Hublot           6.8
# 9340                                Bambi Meets Godzilla           6.5
# 9856                                               Kiwi!           6.5
# 4864                                   The Weeping Camel           7.8
# 9710                                     Fresh Guacamole           7.6
# 11761                                               Alma           7.0
# 7648                     Bobby Fischer Against the World           6.9
# 8861          A Fairly Odd Movie: Grow Up, Timmy Turner!           4.7
# 3423                            The Last American Virgin           6.4
# 4963                                     Turtles Can Fly           7.2
# 9715                                      Soap and Water           6.7
# 6212                                          Ex Drummer           6.6
# 8073                                               Steak           5.1
# 9103                                        Metro Manila           7.2
# 4460                                 Steamboat Bill, Jr.           7.9
# 11060                                    Childhood's End           6.6
# 6327                                          John Adams           7.6
# 10125                                       Preservation           4.8
# 5123                                           Last Days           5.3
# 390             Homeward Bound II: Lost in San Francisco           6.0
# 8491                                         Planet Hulk           6.7
# 10664                                          Smart Ass           6.3
# 6914                                      Blood and Bone           6.6
# 8024   Dragon Ball Z: Broly - The Legendary Super Saiyan           7.3
# 7347                                         Day & Night           7.6
# 798                                            Nosferatu           7.7
# 8478                                                  42           6.8
#
#        vote_count    year                              genres_list  \
# 7895         31.0  2011.0                           Comedy,Romance
# 9130         31.0  2013.0                                    Drama
# 3235         31.0  2002.0                           Comedy,Romance
# 5146         32.0  2005.0            Comedy,Drama,Romance,TV Movie
# 4459         32.0  1928.0                             Drama,Horror
# 9861         33.0  2006.0                          Drama,Animation
# 2795         35.0  1922.0             Crime,Drama,Mystery,Thriller
# 9690         35.0  2014.0                              Documentary
# 9734         37.0  1985.0                    Drama,History,Western
# 12061        37.0  2003.0                Science Fiction,Animation
# 9493         37.0  2014.0                            Romance,Drama
# 10986        37.0  2010.0
# 10242        38.0  2014.0                                   Action
# 3875         38.0  1924.0                            Action,Comedy
# 7711         39.0  2010.0                              Documentary
# 9441         40.0  2013.0          Animation,Comedy,Family,Fantasy
# 9340         40.0  1969.0                         Animation,Comedy
# 9856         41.0  2006.0                         Animation,Action
# 4864         42.0  2003.0                        Documentary,Drama
# 9710         46.0  2012.0                                Animation
# 11761        46.0  2009.0                Animation,Fantasy,Mystery
# 7648         46.0  2011.0                        Documentary,Drama
# 8861         47.0  2011.0                           Family,Fantasy
# 3423         48.0  1982.0                                   Comedy
# 4963         49.0  2005.0                                    Drama
# 9715         50.0  1983.0                                   Comedy
# 6212         50.0  2007.0              Comedy,Crime,Drama,Thriller
# 8073         51.0  2007.0                   Comedy,Science Fiction
# 9103         58.0  2013.0              Crime,Thriller,Drama,Action
# 4460         66.0  1928.0                            Action,Comedy
# 11060        70.0  2015.0  Thriller,TV Movie,Science Fiction,Drama
# 6327         70.0  2008.0                            History,Drama
# 10125        79.0  2014.0                          Thriller,Horror
# 5123         95.0  2005.0                                    Drama
# 390         105.0  1996.0            Adventure,Comedy,Drama,Family
# 8491        108.0  2010.0         Animation,Action,Science Fiction
# 10664       109.0  2014.0                             Comedy,Drama
# 6914        131.0  2009.0                    Drama,Action,Thriller
# 8024        134.0  1993.0               Animation,Adventure,Family
# 7347        272.0  2010.0                         Animation,Family
# 798         373.0  1922.0                           Fantasy,Horror
# 8478        795.0  2013.0                                    Drama
#
#                                production_companies_list  \
# 7895
# 9130                                      Red Lamp Films
# 3235
# 5146
# 4459                                  Universal Pictures
# 9861   Walt Disney Pictures,Walt Disney Animation Stu...
# 2795                                       Uco-Film GmbH
# 9690
# 9734
# 12061                                         Studio 4°C
# 9493                                     Soul Kiss Films
# 10986
# 10242                           General Film Corporation
# 3875                           Buster Keaton Productions
# 7711
# 9441                        ZEILT productions,WATT frame
# 9340
# 9856
# 4864             Hochschule für Fernsehen und Film (HFF)
# 9710
# 11761
# 7648
# 8861   Pacific Bay Entertainment Canada,Pacific Bay E...
# 3423                            Golan-Globus Productions
# 4963                              Bac Films,Mij Film Co.
# 9715                                        Intercapital
# 6212                                           CCCP,Czar
# 8073
# 9103      Oscilloscope Laboratories,Chocolate Frog Films
# 4460                           Buster Keaton Productions
# 11060
# 6327
# 10125                                   Present Pictures
# 5123   HBO Films,Picturehouse Entertainment,Pie Films...
# 390                                 Walt Disney Pictures
# 8491                                    Marvel Animation
# 10664                            Wild Bunch,Stone Angels
# 6914               Michael Mailer Films,Remarkable Films
# 8024                                      Toei Animation
# 7347        Walt Disney Pictures,Pixar Animation Studios
# 798                         Jofa Atelier,Prana-Film GmbH
# 8478                                        Warner Bros.
#
#                                production_countries_list spoken_language_list
# 7895                            United States of America
# 9130   Australia,Lao People's Democratic Republic,Tha...
# 3235
# 5146
# 4459                            United States of America
# 9861                            United States of America
# 2795                                             Germany
# 9690
# 9734
# 12061
# 9493                            United States of America
# 10986
# 10242                                        New Zealand
# 3875                            United States of America
# 7711
# 9441                                   Luxembourg,France
# 9340                                              Canada
# 9856
# 4864                                    Mongolia,Germany
# 9710
# 11761                     Spain,United States of America
# 7648     United States of America,Iceland,United Kingdom
# 8861                            United States of America
# 3423                            United States of America
# 4963                                    Iran,France,Iraq
# 9715                                               Italy
# 6212                                             Belgium
# 8073                                              France
# 9103                                      United Kingdom
# 4460                            United States of America
# 11060
# 6327
# 10125                           United States of America
# 5123                            United States of America
# 390                      Canada,United States of America
# 8491                            United States of America
# 10664                                             France
# 6914                            United States of America
# 8024                                               Japan
# 7347                            United States of America
# 798                                              Germany
# 8478                            United States of America

# %%
# Xóa các dòng có giá trị rỗng trong cột 'spoken_language_list'
data_clear = data_clear[data_clear['spoken_language_list'] != '']

data_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11711 entries, 4508 to 7116
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         11711 non-null  int64
#  1   budget                     11711 non-null  int64
#  2   imdb_id                    11711 non-null  object
#  3   original_language          11711 non-null  object
#  4   original_title             11711 non-null  object
#  5   overview                   11711 non-null  object
#  6   popularity                 11711 non-null  float64
#  7   release_date               11711 non-null  object
#  8   revenue                    11711 non-null  float64
#  9   runtime                    11711 non-null  float64
#  10  status                     11711 non-null  object
#  11  title                      11711 non-null  object
#  12  vote_average               11711 non-null  float64
#  13  vote_count                 11711 non-null  float64
#  14  year                       11711 non-null  float64
#  15  genres_list                11711 non-null  object
#  16  production_companies_list  11711 non-null  object
#  17  production_countries_list  11711 non-null  object
#  18  spoken_language_list       11711 non-null  object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 1.8+ MB

# %%
# Kiểm tra từng cột xem có giá trị rỗng ('') không
empty_columns = (data_clear == '').any()
empty_columns
# Out:
# id                           False
# budget                       False
# imdb_id                      False
# original_language            False
# original_title               False
# overview                     False
# popularity                   False
# release_date                 False
# revenue                      False
# runtime                      False
# status                       False
# title                        False
# vote_average                 False
# vote_count                   False
# year                         False
# genres_list                   True
# production_companies_list     True
# production_countries_list     True
# spoken_language_list         False
# dtype: bool

# %%
data_clear = data_clear[data_clear['genres_list'] != '']
data_clear = data_clear[data_clear['production_companies_list'] != '']
data_clear = data_clear[data_clear['production_countries_list'] != '']

# %%
data_clear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11173 entries, 0 to 11172
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         11173 non-null  int64
#  1   budget                     11173 non-null  int64
#  2   imdb_id                    11173 non-null  object
#  3   original_language          11173 non-null  object
#  4   original_title             11173 non-null  object
#  5   overview                   11173 non-null  object
#  6   popularity                 11173 non-null  float64
#  7   release_date               11173 non-null  object
#  8   revenue                    11173 non-null  float64
#  9   runtime                    11173 non-null  float64
#  10  status                     11173 non-null  object
#  11  title                      11173 non-null  object
#  12  vote_average               11173 non-null  float64
#  13  vote_count                 11173 non-null  float64
#  14  year                       11173 non-null  float64
#  15  genres_list                11173 non-null  object
#  16  production_companies_list  11173 non-null  object
#  17  production_countries_list  11173 non-null  object
#  18  spoken_language_list       11173 non-null  object
# dtypes: float64(6), int64(2), object(11)
# memory usage: 1.6+ MB

# %%
#Lưu dữ liệu ra file Data_Movies_clear.csv
data_clear.sort_values(['release_date'],inplace=True)
data_clear.reset_index(drop=True,inplace=True)
data_clear.to_csv('D:/streamlit_project/Data/Data_Movies_clear.csv', index=None, encoding='utf-8-sig')
